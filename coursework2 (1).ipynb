# %% [markdown]
# # Predicting Early Alzheimer's Using EEG Data and Artificial Intelligence Techniques

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ## 1.1 Research topic
#
# In my exploratory data analysis (EDA) I explored multiple aspects of data pertaining to Alzheimer's disease (AD), including fMRI data and mental state examination scores, gathered from two different sources. Specifically, I extracted data pertaining to early alzheimer's, which is mild cogntive impairment (MCI) that later converts to Alzheimer's. I aimed to prepare a time series data pipeline that could inform the development of a machine learning or deep learning model to not only predict whether a subject with MCI will convert to AD but also how long it would take, based on the rate of progression within a specified amount of years.
#
# Alzheimer's is a neurodegenerative disease that causes memory loss which subsequently leads to the brain being unable to perform vital functions [1]. According to [2], Alzheimer's is the most common form of dementia that effects adults in later stages of life, though a genetic form of Alzheimer's can lead to early-onset Alzheimer's. Due to increases in life expectancy cases of AD are projected to triple by 2050 [3], making it a socioeconmic issue as well as a personal health issue. Although there is research being conducted to develop new tratments [4] and there are currently treatments which slow down progression, there is currently no method of reversing or permenantly halting neurodegeneration, thus, it is important for patients to be treated at the earliest stage possible. Unfortunatly, significant neurodegeneration occurs before individuals present with symptoms of AD [5], so a diagnostic critearia must be developed to diagnose indidivuals with early Alzheimer's before they present with symptoms. In 2011, a revised diagnoistic criteria was devised, infromed by empirical evidence, to include the use of neuroimaging techniques to diagnose Alzheimrer's and other forms of dementia [6-7]. Though, detecting biomarkers of Alzheimer's, especially early Alzheimer's, through inspection of images can be difficult as the difference between normal aging and early Alzheimer's is often subtle, additionally, the difference between stable MCI and early Alzheimer's is much more subtle. Recent research has revealed biomarkers that are clear in brain images and only occur within Alzheimer's patients, namely, amyloid plaques and neurofibrillary tangles [8], however, current neuroimaging techniques required to view these biomarkers can only be performed ex-vivo, in other words, a significant amount of brain tissue must be removed from the body. Although, there is research being conducted to develop in-vivo neuroimaging techniques for these biomarkers [9].
#
# Neurodegeneration leads to cognitive impairment and is a normal part of aging, however, there are pathological levels of cogntive imaprment which are diagnosed as MCI and AD. Individuals with MCI often remain stable, however, there are cases where indidivuals with MCI convert to AD. A meta-analyses by Mitchell and Shiri-Feshki revealed that, amongst 41 clinical studies, there was a 33% conversion rate [10], meaning there is a chance that individuals with MCI will convert to AD, making these individuals a good cohort for neuroimaging testing for early Alzheimer's. Another cohort would be individuals who are genetically predisposed to developing Alzheimer's, such as individuals who have family with Alzheimer's or other genetic markers that are connected to Alzherimer's.
#
#
# ### 1.1.1 Magnetic Resonance Imaging (MRI)
#
# MRI techniques are a most widely used brain imaging techniques due to it's ability to form detailed images of the brain while being non-invasice and safe; it is also possible to adjust parameters according to the structure of interest, making it a flexible technique. MRI techniques emits a magnetic field which effects the spin of atomic nucleus, as the atoms in different areas of the brain have different properties, namely, the difference between distrubution of water in different brain areas means their will be different distrubutions of hydrogen atoms, causing them to generate different frequencies of energy which is imaged with sub-millimeter resolution [11]. Specifically, an MRI image is formed from the magnetic field gradient of the spin of an atoms nuclei when effected by the magnetic field produced by the MRI.
#
# <img src="images/MRI.png">
# MRI of subjects with no AD or MCI, MCI and AD as illustrated in [12, Fig. 1]
#
# Above is an example of an image produced by an MRI scan. There is a slight difference between these two images, namely, the grey area, knwno as grey and white matter, has significantly atrophied in the subject with Alzheimer's.
#
#
# ### 1.1.2 Artificial Intelligence and Advanced Statistical Methods
#
# In recent years, interest in Artificial Intelligence and advanced statistical methods, such as machine learning and deep learning algorithms, has led to a number of publications in the medical field, as well as many other fields. These algorithms are able to identify parameters that can be used to model data, though it works better when a large amount of data are available as the larger the dataset, the closer the algorithm can model the true pattern. A rule of thumb is often 10 times more data than there are parameters, due to technical issues with degrees of freedom, such as overfitting. This presents a problem for AI applied to the medical field as it is difficult to generate large datasets of sensitive data. Thus, methods have been devised to improve the power of AI when less data is available
#
# ### 1.1.3 Computer Vision
#
#
# ## 1.2 Aims and Objectives
#
# During the EDA a logistic regression model was used to find a model that could fit the data, additionally, a Kruskal-Wallis test was used to investigate whether there was a statistical difference between the rate of decay between those who had stable MCI and those who later converted, however, due to the lack of data and possibly also the nature of the data, namely, it being non-linear, a logistic regression model could not be found for this data and the Kruskal-Wallis test did not find a significant difference in rate of decay. Thus, during this project I aim to use more powerful methods to find the function of this data and subsequently build a model that performs better than the previous models used.
#
# ### 1.2.1 Logistic Regression
#
# In the EDA, logistic regression was chosen due to it's flexiblity, namely, it is not reliant on the distribution of the data meeting a certain assumption, so data does not need to be normally distriubted or linearly correlated to the DV. Although logistic regression is a non-linear model it uses the linear regression model to model or fit the data, the prediction or $ \hat{Y} $ is what is computed via a non-linear model
#
# $ \hat{Y}_{i} = \frac{e^{u}}{1+e^{^{u}}} $
# where:
# $ \hat{Y}_{i} $ is the probability that the ith input (i = 1, ..., n) belongs to one of the classes
# u is the linear regression model $ A + B_{1}X_{1} + B_{2}X_{2} + ... + B_{k}X_{k} $ which forms the logit $ ln(\frac{\hat{Y}}{1-\hat{Y}}) = A + \sum B_{j}X_{ij} $ where j = number of coefficients
#
# A mathematical model of logistic regression as seen in [13, eq. (10.1 - 10.3)]
#
# Thus, the linear regression is the natural log of the probability of the input belonging to one class divided by the probability of being in the other group and the coefficients are estimated iteratively using maximum likelihood, similar to neural netowrk models, coefficients are set to small random values and the error is calculated and coefficients are updated to maximize the liklihood of the model fitting the data.
#
# In conclusion, logistic regression is similar to machine and deep learning methods in that it utilises a non-linear function, however, it is only the output that utilises the non-linear function, the data is modelled using linear regression. Thus, this model cannot find non-linear relationships in data.
#
#
# ### 1.2.2 Rate of Atrophy
#
# The equation used to model the rate of atrophy $ \frac{X_{i}-X_{1}}{X_{1}} $ which is a simple equation. During the EDA I performed simple data analysis methods in order to form a benchmark for further analysis. A more advanced methods will be used during this project
#
# ### 1.2.3 Kruskal-Wallis Test
#
# During the EDA a Kruskal-Wallis test was conducted to examine the differences between MMSE scores according to the conversion group, namely, stable MCI and early Alzheimer's. A significant difference (H=65.88, p<0.01) was found among the 2 samples (group 3, conversion from MCI to AD and group 0, no conversion). A post-hoc test will not be necessary as there are 2 variables, so we know that there is a significant difference between the two variables presented. Thus, MMSE will be used as an input to the model used in this project, along with brain volume data.

# %% [markdown]
# # 2. Methods

# %% [markdown]
# ## 2.1 Data cleaning and preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import seaborn as sns
import datetime as dt

# numbers will be displayed up to 3 decimal places, with no scientific notation
pd.options.display.float_format = '{:.3f}'.format
np.set_printoptions(suppress = True)

#only select relevant fields from dataset
fields1 = ['RID','CDGLOBAL','EXAMDATE']
CDR_df = pd.read_csv("CDR.csv",usecols=fields1)

fields2 = ['RID','EICV','EXAMDATE']
IV_df = pd.read_csv("UCSDVOL.csv",usecols=fields2)

fields3 = ['RID','BRAINVOL','EXAMDATE']
BV_df = pd.read_csv("FOXLABBSI_04_29_22.csv",usecols=fields3)

fields4 = ['RID','MMSE','EXAMDATE','AGE']
MMSE_df = pd.read_csv("ADNIMERGE.csv",usecols=fields4)

# %%
class DataCleaning:
    
    
    def __init__(self, *dataframe):
        self.dataframe = list(dataframe)
        
        # allows user to change a variable amount of column names
    def rename_columns(self, **column_dict):
        
        for df in self.dataframe:
            for key,value in column_dict.items():
                df.rename(columns= {key:value},inplace=True)

        # drop duplicates
    def drop_dupl_na(self):
        self.dataframe['MR_Delay'].fillna(0,inplace=True)
        for j in range(len(self.dataframe)):
            for i in range(len(self.dataframe)):
                if j == i:
                    continue
                if CDR_df.iloc[j,1] == 0 & self.dataframe.iloc[j,0] == self.dataframe.iloc[i,0]:
                    self.dataframe.iloc[i].drop(inplace=True)
    
    def get_df(self):
        for df in self.dataframe:
            print(df.head(), '\n', len(df), '\n')
        
class DatetimeConvert(DataCleaning):
    
    #sort by date then calculate days between scans
    # preparing to convert DAYS column to number of days between scans instead of dates
    def sort(self):
        for df in self.dataframe:
            df.loc[:,'DAYS'] = pd.to_datetime(df['DAYS'])
            df.sort_values(by='DAYS', inplace=True)
            df.reset_index(drop=True, inplace=True)
        
    def convert_to_days(self):
        
        for df in self.dataframe:
            date1 = df.groupby(['RID']).DAYS.first() # first date for each subject ID
            date1_idx = date1.index # subject ID's

            for i in date1_idx:
                for j in range(len(df.loc[df['RID']==i])):
                    idx = df.loc[df['RID']==i].index[j]
                    df.loc[idx,'DAYS'] = (df.loc[df['RID']==i].iloc[j,1]-date1[i]).days
                    


class Converted(DataCleaning):
    
    
    def __init__(self, diagnosis1, diagnosis2, *dataframe, group=None):
        
        super().__init__(*dataframe)
        self.diagnosis1 = diagnosis1
        self.diagnosis2 = diagnosis2
        self.group = group
        
        
    def get_group(self):
        # finds converted group using diagnosis and prints group that is called
        Converted_dict = {('ND','MCI'):1, ('ND','AD'):2, ('MCI','AD'):3, ('MCI','ND'):4, ('AD','MCI'):5, ('AD','ND'):6}
        self.group = Converted_dict[(self.diagnosis1,self.diagnosis2)]
        print(f"Converted Group: {self.group}")
        
        
    def diagnose(self):
        # diagnosis based on CDR score
        for df in self.dataframe:
            df.loc[df['CDR'] == 0, 'Group'] = 'ND'
            df.loc[df['CDR'] == 0.5, 'Group'] = 'MCI'
            df.loc[df['CDR'] == 1, 'Group'] = 'AD'
            df.loc[df['CDR'] == 2, 'Group'] = 'AD'
            df.loc[df['CDR'] == 3, 'Group'] = 'AD'
            df.loc[df['CDR'].isnull(), 'Group'] = 'U'
            df.loc[df['CDR'] == -1, 'Group'] = 'U'
        
        
    def setup(self):
    # create a column called counts which groups the RID column and counts the amount of unique values in 
    # each group, this tells me which subjects' diagnosis changed between scans

    # used transform on nunique instead of nunique by itself as nunique returns a series which results in NAN values 
    #if there are no unique values in Group and does not return series of the same length as MRI, transform duplicates 
    # the MRI dataframe with the new column which is more convinient as I do not have to manually change NAN values to 
    # 0 or 1 
        for df in self.dataframe:
            counts = df.groupby('RID').Group.transform('nunique')
            df.loc[:,'counts'] = counts
        
        
    # created a column that counts the amount of times a subject had an MRI, although I will not be using this 
    # column as I will be taking the first and last value of each group as long as they had more than 1 scan
    # it may be useful for later projects 
            IDGROUPED = df.groupby('RID', as_index=True)
            num_MRI = IDGROUPED.RID.transform('count')
            df.loc[:,'num_MRI'] = num_MRI
        
        
    def fill_converted(self, count, print_values=False):
        
        
        
        
        for df in self.dataframe:
            
        # grouped subjects by the amount of scans they had then picked the first and last subject ID
            multigroup_first = df.groupby(['RID','counts'], as_index=True).Group.first()
            multigroup_last = df.groupby(['RID','counts'], as_index=True).Group.last()
        
            first = multigroup_first.filter(regex="\d{1,}, "+count)
            firstindex = first.index.get_level_values(0)
            last = multigroup_last.filter(regex="\d{1,}, "+count)
            
            if print_values == False:
            
                
                
                for i,v in enumerate(first):
                    # index lists are reset on each epoch to avoid bugs, when empty list nothing is updated
                    converted_ind_list = []
                    non_ind_list = []
                    U_ind_list = []
                    
                    # if ith value == self.diagnosis1 & ith value of last df == self.diagnosis2 
                    # they are placed into specified converted group using group dictionary
                    if (v == self.diagnosis1) & (last[firstindex[i]].iloc[0] == self.diagnosis2):
                        # indicies of subject RID in speicified group
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            converted_ind_list.append(rid_index) 
                        
                    # for an unknown reason this line does not update the df if it is in the if statement, 
                    #the if statement has been tested and logic is correct so this line has been taken out 
                    #and list of indidcies is created in if statement to be passed to this line outside if statement
                    
                    # if first and last diagnoses are the same it means that they had a different diagnosis inbetween
                    # these subjects will be put in no conversion group or undiagnosed
                    elif (v == last[firstindex[i]].iloc[0]) & (v != 'U'):
                        
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            non_ind_list.append(rid_index) 
                        
                    
                    # undiagnosed subjects put in converted group none
                    elif (v == 'U') | (last[firstindex[i]].iloc[0] == 'U'):
                        
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            U_ind_list.append(rid_index) 
                
                # index list is used to update columns
                df.loc[converted_ind_list, 'Converted']= self.group
                df.loc[non_ind_list, 'Converted']= 0
                df.loc[U_ind_list, 'Converted']= 'none'
    
    
            if print_values == True:
                converted_ind_list = []
                non_ind_list = []
                U_ind_list = []
                
                for i,v in enumerate(first):
                    # index lists are reset on each epoch to avoid bugs, when empty list nothing is updated
                    
                    #df.loc[1, 'Converted']= 5
                    
                    if (v == self.diagnosis1) & (last[firstindex[i]].iloc[0] == self.diagnosis2):
                        # indicies of subject RID in speicified group
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            converted_ind_list.append(rid_index) 
                        print(i,
                              '\n',
                              'RID of first diagnosis:',
                              firstindex[i],
                              '\n',
                              'row of first diagnosis:',
                              '\n',
                              first.iloc[i:i+1],
                              '\n',
                              'row of last diagnosis:',
                              '\n',
                              last.iloc[i:i+1],
                              '\n',
                              'group:',
                              self.group)
                        
                    # for an unknown reason this line does not update the df if it is in the if statement, 
                    #the if statement has been tested and logic is correct so this line has been taken out 
                    #and list of indidcies is created in if statement to be passed to this line outside if statement
                    
                        
                    #looks for subject id or specified index and updates converted column using group dictionary
                        
                    
                    
                    
                    # if first and last diagnoses are the same it means that they had a different diagnosis inbetween
                    # these subjects will be put in no conversion group
                    elif (v == last[firstindex[i]].iloc[0]) & (v != 'U'):
                        
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            non_ind_list.append(rid_index) 
                        #non_ind_list = list(df.loc[df['RID']==firstindex[i]].index)
                        
                    
                    
                    # undiagnosed subjects put in converted group none
                    elif (v == 'U') | (last[firstindex[i]].iloc[0] == 'U'):
                        
                        for rid_index in df.loc[df['RID']==firstindex[i]].index:
                            U_ind_list.append(rid_index) 
                        #U_ind_list = list(df.loc[df['RID']==firstindex[i]].index)
                    
                    #print(i)
                    #print(converted_ind_list)
                df.loc[converted_ind_list, 'Converted']= self.group
                df.loc[non_ind_list, 'Converted']= 0
                df.loc[U_ind_list, 'Converted']= 'none'
                    
                # prints a space between each group for readability         
                print("\n","\n")

# %% [markdown]
# # Combining ADNI data
#
# Dataframes are combined using an outer merge on RID and EXAMDATE, so rows that have the same RID and EXAMDATE will be merged into one row, if they do not have corresponding data for the other columns these columns will be filled with NaN. All other rows will be still be included in the dataframe
#
# I will be using two dataframes, one with missing values in the CDR column removed and one with missing values in CDR included. This means one dataframe will have data solely for diagnosed subjects and trials and the other will have data for both diagnosed and undiagnosed subjects and trials.

# %%
ADNI = pd.merge(
            pd.merge(
                 pd.merge(MMSE_df,IV_df, how='outer',on=['RID','EXAMDATE']),
                        BV_df,how='outer',on=['RID','EXAMDATE']), 
                            CDR_df,how='outer',on=['RID','EXAMDATE'])

ADNI
# Out:
#         RID    EXAMDATE    AGE   MMSE        EICV  BRAINVOL  CDGLOBAL
# 0         2  2005-09-08 74.300 28.000         NaN       NaN       NaN
# 1         3  2005-09-12 81.300 20.000         NaN       NaN       NaN
# 2         3  2006-03-13 81.300 24.000 1709170.000  1169.872     1.000
# 3         3  2006-09-12 81.300 17.000 1709170.000  1160.033     0.500
# 4         3  2007-09-12 81.300 19.000 1709170.000  1140.089     1.000
# ...     ...         ...    ...    ...         ...       ...       ...
# 36367  7014         NaN    NaN    NaN         NaN       NaN     0.500
# 36368  7112         NaN    NaN    NaN         NaN       NaN     0.000
# 36369  7115         NaN    NaN    NaN         NaN       NaN     0.000
# 36370  7109         NaN    NaN    NaN         NaN       NaN     1.000
# 36371  7116         NaN    NaN    NaN         NaN       NaN     1.000
#
# [36372 rows x 7 columns]

# %%
CleanADNI = DataCleaning(ADNI)
CleanADNI.rename_columns(EXAMDATE='DAYS',CDGLOBAL='CDR')

# %%
ADNI.dropna(subset='DAYS', inplace=True)
# if there are no values in these three columns the row is useless
ADNI.dropna(how='all',subset=['MMSE','EICV','BRAINVOL'], inplace=True)

# D stands for diagnosed
ADNI_D = ADNI.dropna(subset='CDR', inplace=False)

# put them in a list as I will be performing the same preprocessing steps on both dfs so will ues a loop
ADNI_dfs = DatetimeConvert(ADNI,ADNI_D)

# %%
ADNI_dfs.sort()
# Out:
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/3321694694.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'DAYS'] = pd.to_datetime(df['DAYS'])
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/3321694694.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='DAYS', inplace=True)

# %%
ADNI_dfs.convert_to_days()
# Out:
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/3321694694.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[idx,'DAYS'] = (df.loc[df['RID']==i].iloc[j,1]-date1[i]).days

# %% [markdown]
# # Preparing to create converted column

# %% [markdown]
# # Subjects that converted
#
# I can now create a column that will identify the subjects that converted between scans
# This column will contain numerical values that pertain to a specific conversion
#
# No conversion = 0
#
# ND -> MCI = 1
#
# ND -> AD = 2
#
# MCI -> AD = 3
#
# MCI -> ND = 4
#
# AD -> MCI = 5
#
# AD -> ND = 6
#
#
# It is highly unlikely that a subject could convert from AD to MCI or AD to ND unless they were on a new experimental treatment, as alzheimer's is a progressive neurodegenerative disease. It is also unlikely that a subject could convert from MCI to ND but this case is more likely. I have included these keys for completeness, though, subjects in these groups are more likely the result of a data entry error so if any of these keys show up I will investigate further

# %%
  # create a column called counts which groups the RID column and counts the amount of unique values in 
    # each group, this tells me which subjects' diagnosis changed between scans

    # used transform on nunique instead of nunique by itself as nunique returns a series which results in NAN values 
    #if there are no unique values in Group and does not return series of the same length as MRI, transform duplicates 
    # the MRI dataframe with the new column which is more convinient as I do not have to manually change NAN values to 
    # 0 or 1 
df_list = [ADNI,ADNI_D]
for df in df_list:
    df.loc[:,'Converted'] = np.nan
# Out:
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/3890306043.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Converted'] = np.nan

# %%
# Call function for each group with each number of counts
converted_list = [Converted('ND','MCI',ADNI,ADNI_D), 
                  Converted('ND','AD',ADNI,ADNI_D), 
                  Converted('MCI','AD',ADNI,ADNI_D), 
                  Converted('MCI','ND',ADNI,ADNI_D), 
                  Converted('AD','MCI',ADNI,ADNI_D), 
                  Converted('AD','ND',ADNI,ADNI_D)]

for x in converted_list:
    x.get_group()
    print(x.group)
    x.diagnose()
    x.setup()
    x.fill_converted("2", print_values=True)
    x.fill_converted("3", print_values=True)
    x.fill_converted("4", print_values=True)
# Out:
# Converted Group: 1
# 1
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI
#
#
# 1
#  RID of first diagnosis: 5
#  row of first diagnosis:
#  RID  counts
# 5    2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 5    2         MCI
# Name: Group, dtype: object
#  group: 1
# 3
#  RID of first diagnosis: 22
#  row of first diagnosis:
#  RID  counts
# 22   2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 22   2         MCI
# Name: Group, dtype: object
#  group: 1
# 19
#  RID of first diagnosis: 106
#  row of first diagnosis:
#  RID  counts
# 106  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 106  2         MCI
# Name: Group, dtype: object
#  group: 1
# 21
#  RID of first diagnosis: 112
#  row of first diagnosis:
#  RID  counts
# 112  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 112  2         MCI
# Name: Group, dtype: object
#  group: 1
# 22
#  RID of first diagnosis: 118
#  row of first diagnosis:
#  RID  counts
# 118  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 118  2         MCI
# Name: Group, dtype: object
#  group: 1
# 24
#  RID of first diagnosis: 125
#  row of first diagnosis:
#  RID  counts
# 125  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 125  2         MCI
# Name: Group, dtype: object
#  group: 1
# 30
#  RID of first diagnosis: 166
#  row of first diagnosis:
#  RID  counts
# 166  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 166  2         MCI
# Name: Group, dtype: object
#  group: 1
# 31
#  RID of first diagnosis: 169
#  row of first diagnosis:
#  RID  counts
# 169  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 169  2         MCI
# Name: Group, dtype: object
#  group: 1
# 45
#  RID of first diagnosis: 232
#  row of first diagnosis:
#  RID  counts
# 232  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 232  2         MCI
# Name: Group, dtype: object
#  group: 1
# 49
#  RID of first diagnosis: 262
#  row of first diagnosis:
#  RID  counts
# 262  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 262  2         MCI
# Name: Group, dtype: object
#  group: 1
# 59
#  RID of first diagnosis: 327
#  row of first diagnosis:
#  RID  counts
# 327  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 327  2         MCI
# Name: Group, dtype: object
#  group: 1
# 72
#  RID of first diagnosis: 416
#  row of first diagnosis:
#  RID  counts
# 416  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 416  2         MCI
# Name: Group, dtype: object
#  group: 1
# 79
#  RID of first diagnosis: 467
#  row of first diagnosis:
#  RID  counts
# 467  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 467  2         MCI
# Name: Group, dtype: object
#  group: 1
# 84
#  RID of first diagnosis: 500
#  row of first diagnosis:
#  RID  counts
# 500  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 500  2         MCI
# Name: Group, dtype: object
#  group: 1
# 91
#  RID of first diagnosis: 548
#  row of first diagnosis:
#  RID  counts
# 548  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 548  2         MCI
# Name: Group, dtype: object
#  group: 1
# 109
#  RID of first diagnosis: 669
#  row of first diagnosis:
#  RID  counts
# 669  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 669  2         MCI
# Name: Group, dtype: object
#  group: 1
# 111
#  RID of first diagnosis: 679
#  row of first diagnosis:
#  RID  counts
# 679  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 679  2         MCI
# Name: Group, dtype: object
#  group: 1
# 112
#  RID of first diagnosis: 680
#  row of first diagnosis:
#  RID  counts
# 680  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 680  2         MCI
# Name: Group, dtype: object
#  group: 1
# 131
#  RID of first diagnosis: 778
#  row of first diagnosis:
#  RID  counts
# 778  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 778  2         MCI
# Name: Group, dtype: object
#  group: 1
# 132
#  RID of first diagnosis: 779
#  row of first diagnosis:
#  RID  counts
# 779  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 779  2         MCI
# Name: Group, dtype: object
#  group: 1
# 137
#  RID of first diagnosis: 843
#  row of first diagnosis:
#  RID  counts
# 843  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 843  2         MCI
# Name: Group, dtype: object
#  group: 1
# 138
#  RID of first diagnosis: 845
#  row of first diagnosis:
#  RID  counts
# 845  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 845  2         MCI
# Name: Group, dtype: object
#  group: 1
# 147
#  RID of first diagnosis: 883
#  row of first diagnosis:
#  RID  counts
# 883  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 883  2         MCI
# Name: Group, dtype: object
#  group: 1
# 174
#  RID of first diagnosis: 1034
#  row of first diagnosis:
#  RID   counts
# 1034  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1034  2         MCI
# Name: Group, dtype: object
#  group: 1
# 180
#  RID of first diagnosis: 1063
#  row of first diagnosis:
#  RID   counts
# 1063  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1063  2         MCI
# Name: Group, dtype: object
#  group: 1
# 183
#  RID of first diagnosis: 1072
#  row of first diagnosis:
#  RID   counts
# 1072  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1072  2         MCI
# Name: Group, dtype: object
#  group: 1
# 198
#  RID of first diagnosis: 1169
#  row of first diagnosis:
#  RID   counts
# 1169  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1169  2         MCI
# Name: Group, dtype: object
#  group: 1
# 200
#  RID of first diagnosis: 1202
#  row of first diagnosis:
#  RID   counts
# 1202  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1202  2         MCI
# Name: Group, dtype: object
#  group: 1
# 209
#  RID of first diagnosis: 1268
#  row of first diagnosis:
#  RID   counts
# 1268  2         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1268  2         MCI
# Name: Group, dtype: object
#  group: 1
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[U_ind_list, 'Converted']= 'none'
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI
#
#
#
#
#
#
#
#
# Converted Group: 2
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#  RID of first diagnosis: 898
#  row of first diagnosis:
#  RID  counts
# 898  4         ND
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 898  4         AD
# Name: Group, dtype: object
#  group: 2
#
#
#
# Converted Group: 3
# 3
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI
#
#
# 2
#  RID of first diagnosis: 10
#  row of first diagnosis:
#  RID  counts
# 10   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 10   2         AD
# Name: Group, dtype: object
#  group: 3
# 4
#  RID of first diagnosis: 30
#  row of first diagnosis:
#  RID  counts
# 30   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 30   2         AD
# Name: Group, dtype: object
#  group: 3
# 7
#  RID of first diagnosis: 41
#  row of first diagnosis:
#  RID  counts
# 41   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 41   2         AD
# Name: Group, dtype: object
#  group: 3
# 8
#  RID of first diagnosis: 42
#  row of first diagnosis:
#  RID  counts
# 42   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 42   2         AD
# Name: Group, dtype: object
#  group: 3
# 9
#  RID of first diagnosis: 54
#  row of first diagnosis:
#  RID  counts
# 54   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 54   2         AD
# Name: Group, dtype: object
#  group: 3
# 10
#  RID of first diagnosis: 57
#  row of first diagnosis:
#  RID  counts
# 57   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 57   2         AD
# Name: Group, dtype: object
#  group: 3
# 11
#  RID of first diagnosis: 76
#  row of first diagnosis:
#  RID  counts
# 76   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 76   2         AD
# Name: Group, dtype: object
#  group: 3
# 12
#  RID of first diagnosis: 77
#  row of first diagnosis:
#  RID  counts
# 77   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 77   2         AD
# Name: Group, dtype: object
#  group: 3
# 13
#  RID of first diagnosis: 80
#  row of first diagnosis:
#  RID  counts
# 80   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 80   2         AD
# Name: Group, dtype: object
#  group: 3
# 14
#  RID of first diagnosis: 83
#  row of first diagnosis:
#  RID  counts
# 83   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 83   2         AD
# Name: Group, dtype: object
#  group: 3
# 16
#  RID of first diagnosis: 88
#  row of first diagnosis:
#  RID  counts
# 88   2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 88   2         AD
# Name: Group, dtype: object
#  group: 3
# 18
#  RID of first diagnosis: 102
#  row of first diagnosis:
#  RID  counts
# 102  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 102  2         AD
# Name: Group, dtype: object
#  group: 3
# 20
#  RID of first diagnosis: 108
#  row of first diagnosis:
#  RID  counts
# 108  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 108  2         AD
# Name: Group, dtype: object
#  group: 3
# 26
#  RID of first diagnosis: 128
#  row of first diagnosis:
#  RID  counts
# 128  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 128  2         AD
# Name: Group, dtype: object
#  group: 3
# 27
#  RID of first diagnosis: 139
#  row of first diagnosis:
#  RID  counts
# 139  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 139  2         AD
# Name: Group, dtype: object
#  group: 3
# 28
#  RID of first diagnosis: 141
#  row of first diagnosis:
#  RID  counts
# 141  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 141  2         AD
# Name: Group, dtype: object
#  group: 3
# 29
#  RID of first diagnosis: 155
#  row of first diagnosis:
#  RID  counts
# 155  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 155  2         AD
# Name: Group, dtype: object
#  group: 3
# 32
#  RID of first diagnosis: 179
#  row of first diagnosis:
#  RID  counts
# 179  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 179  2         AD
# Name: Group, dtype: object
#  group: 3
# 35
#  RID of first diagnosis: 190
#  row of first diagnosis:
#  RID  counts
# 190  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 190  2         AD
# Name: Group, dtype: object
#  group: 3
# 36
#  RID of first diagnosis: 195
#  row of first diagnosis:
#  RID  counts
# 195  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 195  2         AD
# Name: Group, dtype: object
#  group: 3
# 38
#  RID of first diagnosis: 204
#  row of first diagnosis:
#  RID  counts
# 204  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 204  2         AD
# Name: Group, dtype: object
#  group: 3
# 40
#  RID of first diagnosis: 217
#  row of first diagnosis:
#  RID  counts
# 217  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 217  2         AD
# Name: Group, dtype: object
#  group: 3
# 41
#  RID of first diagnosis: 222
#  row of first diagnosis:
#  RID  counts
# 222  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 222  2         AD
# Name: Group, dtype: object
#  group: 3
# 42
#  RID of first diagnosis: 223
#  row of first diagnosis:
#  RID  counts
# 223  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 223  2         AD
# Name: Group, dtype: object
#  group: 3
# 44
#  RID of first diagnosis: 231
#  row of first diagnosis:
#  RID  counts
# 231  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 231  2         AD
# Name: Group, dtype: object
#  group: 3
# 46
#  RID of first diagnosis: 240
#  row of first diagnosis:
#  RID  counts
# 240  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 240  2         AD
# Name: Group, dtype: object
#  group: 3
# 47
#  RID of first diagnosis: 249
#  row of first diagnosis:
#  RID  counts
# 249  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 249  2         AD
# Name: Group, dtype: object
#  group: 3
# 48
#  RID of first diagnosis: 256
#  row of first diagnosis:
#  RID  counts
# 256  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 256  2         AD
# Name: Group, dtype: object
#  group: 3
# 50
#  RID of first diagnosis: 286
#  row of first diagnosis:
#  RID  counts
# 286  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 286  2         AD
# Name: Group, dtype: object
#  group: 3
# 52
#  RID of first diagnosis: 293
#  row of first diagnosis:
#  RID  counts
# 293  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 293  2         AD
# Name: Group, dtype: object
#  group: 3
# 53
#  RID of first diagnosis: 294
#  row of first diagnosis:
#  RID  counts
# 294  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 294  2         AD
# Name: Group, dtype: object
#  group: 3
# 57
#  RID of first diagnosis: 310
#  row of first diagnosis:
#  RID  counts
# 310  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 310  2         AD
# Name: Group, dtype: object
#  group: 3
# 60
#  RID of first diagnosis: 331
#  row of first diagnosis:
#  RID  counts
# 331  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 331  2         AD
# Name: Group, dtype: object
#  group: 3
# 61
#  RID of first diagnosis: 344
#  row of first diagnosis:
#  RID  counts
# 344  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 344  2         AD
# Name: Group, dtype: object
#  group: 3
# 62
#  RID of first diagnosis: 362
#  row of first diagnosis:
#  RID  counts
# 362  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 362  2         AD
# Name: Group, dtype: object
#  group: 3
# 63
#  RID of first diagnosis: 372
#  row of first diagnosis:
#  RID  counts
# 372  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 372  2         AD
# Name: Group, dtype: object
#  group: 3
# 64
#  RID of first diagnosis: 374
#  row of first diagnosis:
#  RID  counts
# 374  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 374  2         AD
# Name: Group, dtype: object
#  group: 3
# 66
#  RID of first diagnosis: 388
#  row of first diagnosis:
#  RID  counts
# 388  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 388  2         AD
# Name: Group, dtype: object
#  group: 3
# 67
#  RID of first diagnosis: 394
#  row of first diagnosis:
#  RID  counts
# 394  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 394  2         AD
# Name: Group, dtype: object
#  group: 3
# 70
#  RID of first diagnosis: 406
#  row of first diagnosis:
#  RID  counts
# 406  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 406  2         AD
# Name: Group, dtype: object
#  group: 3
# 71
#  RID of first diagnosis: 408
#  row of first diagnosis:
#  RID  counts
# 408  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 408  2         AD
# Name: Group, dtype: object
#  group: 3
# 74
#  RID of first diagnosis: 434
#  row of first diagnosis:
#  RID  counts
# 434  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 434  2         AD
# Name: Group, dtype: object
#  group: 3
# 76
#  RID of first diagnosis: 450
#  row of first diagnosis:
#  RID  counts
# 450  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 450  2         AD
# Name: Group, dtype: object
#  group: 3
# 78
#  RID of first diagnosis: 461
#  row of first diagnosis:
#  RID  counts
# 461  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 461  2         AD
# Name: Group, dtype: object
#  group: 3
# 82
#  RID of first diagnosis: 487
#  row of first diagnosis:
#  RID  counts
# 487  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 487  2         AD
# Name: Group, dtype: object
#  group: 3
# 85
#  RID of first diagnosis: 507
#  row of first diagnosis:
#  RID  counts
# 507  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 507  2         AD
# Name: Group, dtype: object
#  group: 3
# 86
#  RID of first diagnosis: 513
#  row of first diagnosis:
#  RID  counts
# 513  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 513  2         AD
# Name: Group, dtype: object
#  group: 3
# 90
#  RID of first diagnosis: 539
#  row of first diagnosis:
#  RID  counts
# 539  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 539  2         AD
# Name: Group, dtype: object
#  group: 3
# 92
#  RID of first diagnosis: 566
#  row of first diagnosis:
#  RID  counts
# 566  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 566  2         AD
# Name: Group, dtype: object
#  group: 3
# 93
#  RID of first diagnosis: 568
#  row of first diagnosis:
#  RID  counts
# 568  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 568  2         AD
# Name: Group, dtype: object
#  group: 3
# 94
#  RID of first diagnosis: 572
#  row of first diagnosis:
#  RID  counts
# 572  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 572  2         AD
# Name: Group, dtype: object
#  group: 3
# 96
#  RID of first diagnosis: 577
#  row of first diagnosis:
#  RID  counts
# 577  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 577  2         AD
# Name: Group, dtype: object
#  group: 3
# 98
#  RID of first diagnosis: 604
#  row of first diagnosis:
#  RID  counts
# 604  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 604  2         AD
# Name: Group, dtype: object
#  group: 3
# 100
#  RID of first diagnosis: 608
#  row of first diagnosis:
#  RID  counts
# 608  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 608  2         AD
# Name: Group, dtype: object
#  group: 3
# 101
#  RID of first diagnosis: 611
#  row of first diagnosis:
#  RID  counts
# 611  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 611  2         AD
# Name: Group, dtype: object
#  group: 3
# 103
#  RID of first diagnosis: 633
#  row of first diagnosis:
#  RID  counts
# 633  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 633  2         AD
# Name: Group, dtype: object
#  group: 3
# 105
#  RID of first diagnosis: 644
#  row of first diagnosis:
#  RID  counts
# 644  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 644  2         AD
# Name: Group, dtype: object
#  group: 3
# 106
#  RID of first diagnosis: 649
#  row of first diagnosis:
#  RID  counts
# 649  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 649  2         AD
# Name: Group, dtype: object
#  group: 3
# 110
#  RID of first diagnosis: 675
#  row of first diagnosis:
#  RID  counts
# 675  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 675  2         AD
# Name: Group, dtype: object
#  group: 3
# 113
#  RID of first diagnosis: 682
#  row of first diagnosis:
#  RID  counts
# 682  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 682  2         AD
# Name: Group, dtype: object
#  group: 3
# 115
#  RID of first diagnosis: 695
#  row of first diagnosis:
#  RID  counts
# 695  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 695  2         AD
# Name: Group, dtype: object
#  group: 3
# 116
#  RID of first diagnosis: 696
#  row of first diagnosis:
#  RID  counts
# 696  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 696  2         AD
# Name: Group, dtype: object
#  group: 3
# 117
#  RID of first diagnosis: 697
#  row of first diagnosis:
#  RID  counts
# 697  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 697  2         AD
# Name: Group, dtype: object
#  group: 3
# 118
#  RID of first diagnosis: 708
#  row of first diagnosis:
#  RID  counts
# 708  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 708  2         AD
# Name: Group, dtype: object
#  group: 3
# 120
#  RID of first diagnosis: 723
#  row of first diagnosis:
#  RID  counts
# 723  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 723  2         AD
# Name: Group, dtype: object
#  group: 3
# 123
#  RID of first diagnosis: 733
#  row of first diagnosis:
#  RID  counts
# 733  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 733  2         AD
# Name: Group, dtype: object
#  group: 3
# 125
#  RID of first diagnosis: 750
#  row of first diagnosis:
#  RID  counts
# 750  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 750  2         AD
# Name: Group, dtype: object
#  group: 3
# 126
#  RID of first diagnosis: 752
#  row of first diagnosis:
#  RID  counts
# 752  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 752  2         AD
# Name: Group, dtype: object
#  group: 3
# 127
#  RID of first diagnosis: 754
#  row of first diagnosis:
#  RID  counts
# 754  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 754  2         AD
# Name: Group, dtype: object
#  group: 3
# 128
#  RID of first diagnosis: 759
#  row of first diagnosis:
#  RID  counts
# 759  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 759  2         AD
# Name: Group, dtype: object
#  group: 3
# 135
#  RID of first diagnosis: 832
#  row of first diagnosis:
#  RID  counts
# 832  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 832  2         AD
# Name: Group, dtype: object
#  group: 3
# 136
#  RID of first diagnosis: 834
#  row of first diagnosis:
#  RID  counts
# 834  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 834  2         AD
# Name: Group, dtype: object
#  group: 3
# 139
#  RID of first diagnosis: 852
#  row of first diagnosis:
#  RID  counts
# 852  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 852  2         AD
# Name: Group, dtype: object
#  group: 3
# 141
#  RID of first diagnosis: 856
#  row of first diagnosis:
#  RID  counts
# 856  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 856  2         AD
# Name: Group, dtype: object
#  group: 3
# 142
#  RID of first diagnosis: 861
#  row of first diagnosis:
#  RID  counts
# 861  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 861  2         AD
# Name: Group, dtype: object
#  group: 3
# 144
#  RID of first diagnosis: 873
#  row of first diagnosis:
#  RID  counts
# 873  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 873  2         AD
# Name: Group, dtype: object
#  group: 3
# 145
#  RID of first diagnosis: 874
#  row of first diagnosis:
#  RID  counts
# 874  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 874  2         AD
# Name: Group, dtype: object
#  group: 3
# 146
#  RID of first diagnosis: 878
#  row of first diagnosis:
#  RID  counts
# 878  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 878  2         AD
# Name: Group, dtype: object
#  group: 3
# 148
#  RID of first diagnosis: 887
#  row of first diagnosis:
#  RID  counts
# 887  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 887  2         AD
# Name: Group, dtype: object
#  group: 3
# 150
#  RID of first diagnosis: 892
#  row of first diagnosis:
#  RID  counts
# 892  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 892  2         AD
# Name: Group, dtype: object
#  group: 3
# 152
#  RID of first diagnosis: 906
#  row of first diagnosis:
#  RID  counts
# 906  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 906  2         AD
# Name: Group, dtype: object
#  group: 3
# 153
#  RID of first diagnosis: 909
#  row of first diagnosis:
#  RID  counts
# 909  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 909  2         AD
# Name: Group, dtype: object
#  group: 3
# 154
#  RID of first diagnosis: 915
#  row of first diagnosis:
#  RID  counts
# 915  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 915  2         AD
# Name: Group, dtype: object
#  group: 3
# 155
#  RID of first diagnosis: 922
#  row of first diagnosis:
#  RID  counts
# 922  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 922  2         AD
# Name: Group, dtype: object
#  group: 3
# 157
#  RID of first diagnosis: 930
#  row of first diagnosis:
#  RID  counts
# 930  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 930  2         AD
# Name: Group, dtype: object
#  group: 3
# 158
#  RID of first diagnosis: 938
#  row of first diagnosis:
#  RID  counts
# 938  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 938  2         AD
# Name: Group, dtype: object
#  group: 3
# 159
#  RID of first diagnosis: 941
#  row of first diagnosis:
#  RID  counts
# 941  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 941  2         AD
# Name: Group, dtype: object
#  group: 3
# 161
#  RID of first diagnosis: 952
#  row of first diagnosis:
#  RID  counts
# 952  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 952  2         AD
# Name: Group, dtype: object
#  group: 3
# 162
#  RID of first diagnosis: 954
#  row of first diagnosis:
#  RID  counts
# 954  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 954  2         AD
# Name: Group, dtype: object
#  group: 3
# 164
#  RID of first diagnosis: 982
#  row of first diagnosis:
#  RID  counts
# 982  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 982  2         AD
# Name: Group, dtype: object
#  group: 3
# 165
#  RID of first diagnosis: 987
#  row of first diagnosis:
#  RID  counts
# 987  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 987  2         AD
# Name: Group, dtype: object
#  group: 3
# 166
#  RID of first diagnosis: 995
#  row of first diagnosis:
#  RID  counts
# 995  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 995  2         AD
# Name: Group, dtype: object
#  group: 3
# 168
#  RID of first diagnosis: 997
#  row of first diagnosis:
#  RID  counts
# 997  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 997  2         AD
# Name: Group, dtype: object
#  group: 3
# 171
#  RID of first diagnosis: 1010
#  row of first diagnosis:
#  RID   counts
# 1010  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1010  2         AD
# Name: Group, dtype: object
#  group: 3
# 173
#  RID of first diagnosis: 1027
#  row of first diagnosis:
#  RID   counts
# 1027  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1027  2         AD
# Name: Group, dtype: object
#  group: 3
# 177
#  RID of first diagnosis: 1054
#  row of first diagnosis:
#  RID   counts
# 1054  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1054  2         AD
# Name: Group, dtype: object
#  group: 3
# 178
#  RID of first diagnosis: 1056
#  row of first diagnosis:
#  RID   counts
# 1056  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1056  2         AD
# Name: Group, dtype: object
#  group: 3
# 179
#  RID of first diagnosis: 1057
#  row of first diagnosis:
#  RID   counts
# 1057  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1057  2         AD
# Name: Group, dtype: object
#  group: 3
# 181
#  RID of first diagnosis: 1066
#  row of first diagnosis:
#  RID   counts
# 1066  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1066  2         AD
# Name: Group, dtype: object
#  group: 3
# 182
#  RID of first diagnosis: 1070
#  row of first diagnosis:
#  RID   counts
# 1070  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1070  2         AD
# Name: Group, dtype: object
#  group: 3
# 187
#  RID of first diagnosis: 1088
#  row of first diagnosis:
#  RID   counts
# 1088  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1088  2         AD
# Name: Group, dtype: object
#  group: 3
# 189
#  RID of first diagnosis: 1101
#  row of first diagnosis:
#  RID   counts
# 1101  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1101  2         AD
# Name: Group, dtype: object
#  group: 3
# 191
#  RID of first diagnosis: 1121
#  row of first diagnosis:
#  RID   counts
# 1121  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1121  2         AD
# Name: Group, dtype: object
#  group: 3
# 192
#  RID of first diagnosis: 1126
#  row of first diagnosis:
#  RID   counts
# 1126  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1126  2         AD
# Name: Group, dtype: object
#  group: 3
# 193
#  RID of first diagnosis: 1130
#  row of first diagnosis:
#  RID   counts
# 1130  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1130  2         AD
# Name: Group, dtype: object
#  group: 3
# 194
#  RID of first diagnosis: 1138
#  row of first diagnosis:
#  RID   counts
# 1138  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1138  2         AD
# Name: Group, dtype: object
#  group: 3
# 195
#  RID of first diagnosis: 1148
#  row of first diagnosis:
#  RID   counts
# 1148  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1148  2         AD
# Name: Group, dtype: object
#  group: 3
# 197
#  RID of first diagnosis: 1161
#  row of first diagnosis:
#  RID   counts
# 1161  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1161  2         AD
# Name: Group, dtype: object
#  group: 3
# 201
#  RID of first diagnosis: 1209
#  row of first diagnosis:
#  RID   counts
# 1209  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1209  2         AD
# Name: Group, dtype: object
#  group: 3
# 203
#  RID of first diagnosis: 1213
#  row of first diagnosis:
#  RID   counts
# 1213  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1213  2         AD
# Name: Group, dtype: object
#  group: 3
# 204
#  RID of first diagnosis: 1217
#  row of first diagnosis:
#  RID   counts
# 1217  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1217  2         AD
# Name: Group, dtype: object
#  group: 3
# 205
#  RID of first diagnosis: 1225
#  row of first diagnosis:
#  RID   counts
# 1225  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1225  2         AD
# Name: Group, dtype: object
#  group: 3
# 206
#  RID of first diagnosis: 1231
#  row of first diagnosis:
#  RID   counts
# 1231  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1231  2         AD
# Name: Group, dtype: object
#  group: 3
# 207
#  RID of first diagnosis: 1243
#  row of first diagnosis:
#  RID   counts
# 1243  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1243  2         AD
# Name: Group, dtype: object
#  group: 3
# 210
#  RID of first diagnosis: 1271
#  row of first diagnosis:
#  RID   counts
# 1271  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1271  2         AD
# Name: Group, dtype: object
#  group: 3
# 212
#  RID of first diagnosis: 1282
#  row of first diagnosis:
#  RID   counts
# 1282  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1282  2         AD
# Name: Group, dtype: object
#  group: 3
# 214
#  RID of first diagnosis: 1285
#  row of first diagnosis:
#  RID   counts
# 1285  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1285  2         AD
# Name: Group, dtype: object
#  group: 3
# 215
#  RID of first diagnosis: 1290
#  row of first diagnosis:
#  RID   counts
# 1290  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1290  2         AD
# Name: Group, dtype: object
#  group: 3
# 216
#  RID of first diagnosis: 1292
#  row of first diagnosis:
#  RID   counts
# 1292  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1292  2         AD
# Name: Group, dtype: object
#  group: 3
# 217
#  RID of first diagnosis: 1296
#  row of first diagnosis:
#  RID   counts
# 1296  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1296  2         AD
# Name: Group, dtype: object
#  group: 3
# 219
#  RID of first diagnosis: 1308
#  row of first diagnosis:
#  RID   counts
# 1308  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1308  2         AD
# Name: Group, dtype: object
#  group: 3
# 220
#  RID of first diagnosis: 1311
#  row of first diagnosis:
#  RID   counts
# 1311  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1311  2         AD
# Name: Group, dtype: object
#  group: 3
# 221
#  RID of first diagnosis: 1346
#  row of first diagnosis:
#  RID   counts
# 1346  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1346  2         AD
# Name: Group, dtype: object
#  group: 3
# 222
#  RID of first diagnosis: 1351
#  row of first diagnosis:
#  RID   counts
# 1351  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1351  2         AD
# Name: Group, dtype: object
#  group: 3
# 224
#  RID of first diagnosis: 1377
#  row of first diagnosis:
#  RID   counts
# 1377  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1377  2         AD
# Name: Group, dtype: object
#  group: 3
# 226
#  RID of first diagnosis: 1384
#  row of first diagnosis:
#  RID   counts
# 1384  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1384  2         AD
# Name: Group, dtype: object
#  group: 3
# 227
#  RID of first diagnosis: 1387
#  row of first diagnosis:
#  RID   counts
# 1387  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1387  2         AD
# Name: Group, dtype: object
#  group: 3
# 228
#  RID of first diagnosis: 1389
#  row of first diagnosis:
#  RID   counts
# 1389  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1389  2         AD
# Name: Group, dtype: object
#  group: 3
# 229
#  RID of first diagnosis: 1393
#  row of first diagnosis:
#  RID   counts
# 1393  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1393  2         AD
# Name: Group, dtype: object
#  group: 3
# 230
#  RID of first diagnosis: 1394
#  row of first diagnosis:
#  RID   counts
# 1394  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1394  2         AD
# Name: Group, dtype: object
#  group: 3
# 231
#  RID of first diagnosis: 1398
#  row of first diagnosis:
#  RID   counts
# 1398  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1398  2         AD
# Name: Group, dtype: object
#  group: 3
# 233
#  RID of first diagnosis: 1427
#  row of first diagnosis:
#  RID   counts
# 1427  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1427  2         AD
# Name: Group, dtype: object
#  group: 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converted Group: 4
# 4
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI
#
#
# 25
#  RID of first diagnosis: 127
#  row of first diagnosis:
#  RID  counts
# 127  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 127  2         ND
# Name: Group, dtype: object
#  group: 4
# 65
#  RID of first diagnosis: 384
#  row of first diagnosis:
#  RID  counts
# 384  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 384  2         ND
# Name: Group, dtype: object
#  group: 4
# 73
#  RID of first diagnosis: 422
#  row of first diagnosis:
#  RID  counts
# 422  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 422  2         ND
# Name: Group, dtype: object
#  group: 4
# 77
#  RID of first diagnosis: 459
#  row of first diagnosis:
#  RID  counts
# 459  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 459  2         ND
# Name: Group, dtype: object
#  group: 4
# 83
#  RID of first diagnosis: 488
#  row of first diagnosis:
#  RID  counts
# 488  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 488  2         ND
# Name: Group, dtype: object
#  group: 4
# 97
#  RID of first diagnosis: 579
#  row of first diagnosis:
#  RID  counts
# 579  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 579  2         ND
# Name: Group, dtype: object
#  group: 4
# 108
#  RID of first diagnosis: 668
#  row of first diagnosis:
#  RID  counts
# 668  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 668  2         ND
# Name: Group, dtype: object
#  group: 4
# 119
#  RID of first diagnosis: 722
#  row of first diagnosis:
#  RID  counts
# 722  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 722  2         ND
# Name: Group, dtype: object
#  group: 4
# 133
#  RID of first diagnosis: 800
#  row of first diagnosis:
#  RID  counts
# 800  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 800  2         ND
# Name: Group, dtype: object
#  group: 4
# 151
#  RID of first diagnosis: 896
#  row of first diagnosis:
#  RID  counts
# 896  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 896  2         ND
# Name: Group, dtype: object
#  group: 4
# 188
#  RID of first diagnosis: 1092
#  row of first diagnosis:
#  RID   counts
# 1092  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1092  2         ND
# Name: Group, dtype: object
#  group: 4
# 199
#  RID of first diagnosis: 1188
#  row of first diagnosis:
#  RID   counts
# 1188  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1188  2         ND
# Name: Group, dtype: object
#  group: 4
# 223
#  RID of first diagnosis: 1352
#  row of first diagnosis:
#  RID   counts
# 1352  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1352  2         ND
# Name: Group, dtype: object
#  group: 4
# 232
#  RID of first diagnosis: 1408
#  row of first diagnosis:
#  RID   counts
# 1408  2         MCI
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID   counts
# 1408  2         ND
# Name: Group, dtype: object
#  group: 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converted Group: 5
# 5
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI
#
#
# 167
#  RID of first diagnosis: 996
#  row of first diagnosis:
#  RID  counts
# 996  2         AD
# Name: Group, dtype: object
#  row of last diagnosis:
#  RID  counts
# 996  2         MCI
# Name: Group, dtype: object
#  group: 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converted Group: 6
# 6
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'counts'] = counts
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/633708011.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'num_MRI'] = num_MRI

# %%
# those with only one diagnosis did not convert
for df in df_list:
    df.loc[(df['counts'] == 1), 'Converted']=0
    df.loc[df['Group'] == 'U', 'Converted']= 'none'

# %%
ADNI_D
# Out:
#        RID  DAYS    AGE   MMSE        EICV  BRAINVOL   CDR Converted Group  \
# 0      128     0    NaN    NaN 1237130.000   907.098 0.500         3   MCI
# 1      161     0    NaN    NaN 1367960.000  1026.524 0.500         0   MCI
# 2        2     0 74.300 28.000         NaN       NaN 0.000         0    ND
# 3        5     0 73.700 29.000 1599490.000  1164.724 0.000     1.000    ND
# 4        3     0 81.300 24.000 1709170.000  1169.872 1.000         0    AD
# ...    ...   ...    ...    ...         ...       ...   ...       ...   ...
# 2997   919  1289 62.400 30.000         NaN       NaN 0.500         0   MCI
# 2998   505  1306 79.700 29.000         NaN       NaN 0.500         0   MCI
# 2999   969  1296 70.000 29.000         NaN       NaN 0.000         0    ND
# 3000   865  1281 73.500 24.000         NaN       NaN 0.500         0   MCI
# 3001  1077  1279 83.300 29.000         NaN       NaN 0.500         0   MCI
#
#       counts  num_MRI
# 0          2        7
# 1          1        6
# 2          1        2
# 3          2        4
# 4          2        3
# ...      ...      ...
# 2997       1        6
# 2998       1        9
# 2999       2        5
# 3000       2        6
# 3001       2        6
#
# [3002 rows x 11 columns]

# %% [markdown]
# # Univariate Outliers / Z scores
#
# I will compute the z scores of the eTIV, nBWV for each group and analyse values that are  ±  3.29
#
# I am simply looking for outliers within each group so I will include all subjects with a specific diagnosis at any time
#
# I will not include the undiagnosed group,thiull only be computing scores for the dataframe with no missing values (ADNI_D)

# %%
# Intracranial volume
AD_IV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='AD', 'EICV'])
MCI_IV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='MCI', 'EICV'])
ND_IV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='ND', 'EICV'])

# %%
IV_ZSCORE_AD = stats.zscore(AD_IV_D,nan_policy='omit')
print(IV_ZSCORE_AD[IV_ZSCORE_AD>3.28])
print(IV_ZSCORE_AD[IV_ZSCORE_AD<-3.28])
# Out:
# []
# []

# %%
IV_ZSCORE_MCI = stats.zscore(MCI_IV_D,nan_policy='omit')
print(IV_ZSCORE_MCI[IV_ZSCORE_MCI>3.28])
print(IV_ZSCORE_MCI[IV_ZSCORE_MCI<-3.28])
# Out:
# []
# []

# %%
IV_ZSCORE_ND = stats.zscore(ND_IV_D,nan_policy='omit')
print(IV_ZSCORE_ND[IV_ZSCORE_ND>3.28])
print(IV_ZSCORE_ND[IV_ZSCORE_ND<-3.28])
# Out:
# []
# []

# %%
# Whole brain volume
AD_BV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='AD', 'BRAINVOL'])
MCI_BV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='MCI', 'BRAINVOL'])
ND_BV_D = np.array(ADNI_D.loc[ADNI_D['Group']=='ND', 'BRAINVOL'])

# %%
BV_ZSCORE_AD = stats.zscore(AD_BV_D,nan_policy='omit')
print(BV_ZSCORE_AD[BV_ZSCORE_AD>3.28])
print(BV_ZSCORE_AD[BV_ZSCORE_AD<-3.28])
# Out:
# [3.5386308]
# []

# %%
BV_ZSCORE_MCI = stats.zscore(MCI_BV_D,nan_policy='omit')
print(BV_ZSCORE_MCI[BV_ZSCORE_MCI>3.28])
print(BV_ZSCORE_MCI[BV_ZSCORE_MCI<-3.28])
# Out:
# []
# []

# %%
BV_ZSCORE_ND = stats.zscore(ND_BV_D,nan_policy='omit')
print(BV_ZSCORE_ND[BV_ZSCORE_ND>3.28])
print(BV_ZSCORE_ND[BV_ZSCORE_ND<-3.28])
# Out:
# []
# []

# %% [markdown]
# # Locating the outlier
#
# As the zscore function used only gives the zscore value I will need to find the position of this value manually.
#
#
# The equation for caluclating a zscore is:
#
# $ Z = \frac{(x-mean)}{sd} $
#
# Thus, the equation to find the x value, in other words, to transform the zscore back to its original value, which in this case is the BRAINVOL, is:
#
# $ x = (Z\cdot sd) + mean $

# %%
outlier = np.nanmean(AD_BV_D) + ((BV_ZSCORE_AD[BV_ZSCORE_AD>3.28])*np.nanstd(AD_BV_D))
print(outlier)
ADNI_D.loc[ADNI_D['BRAINVOL']==float(outlier)]
# Out:
# [1400.909]
#      RID DAYS    AGE   MMSE        EICV  BRAINVOL   CDR Converted Group  \
# 754  300  195 56.400 28.000 1803380.000  1400.909 1.000         0    AD
#
#      counts  num_MRI
# 754       2        5

# %%
ADNI_D.drop(754,inplace=True)
# Out:
# /var/folders/96/ntd6ngxn5klgfg7ylpwj8n_h0000gn/T/ipykernel_1597/3224472792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ADNI_D.drop(754,inplace=True)

# %% [markdown]
# as MMSE scores are interval data a z score between 3 and 4 will not exist. I will look for outliers using a histogram instead

# %%
x = ADNI_D.loc[ADNI_D['Group']=='ND', 'MMSE'].dropna()
plt.hist(x,bins=10)
plt.show()

# %%
print(ADNI_D[(ADNI_D['MMSE']<=25)&(ADNI_D['Group']=='ND')])
print(len(ADNI_D[(ADNI_D['AGE']>=90)&(ADNI_D['Group']=='ND')]))
print(len(ADNI_D[ADNI_D['AGE']>=90]))
# Out:
#        RID DAYS    AGE   MMSE        EICV  BRAINVOL   CDR Group  counts  \
# 142    245    0 73.800 25.000         NaN       NaN 0.000    ND       1
# 513     70  199 74.000 25.000 1600860.000  1156.511 0.000    ND       1
# 560    262  145 85.800 24.000         NaN       NaN 0.000    ND       2
# 879   1021    0 86.900 24.000 1296930.000   883.824 0.000    ND       1
# 1234   296  355 79.100 22.000 1497450.000       NaN 0.000    ND       2
# 1507   401  399 63.900 25.000         NaN       NaN 0.000    ND       2
# 2080   669  541 63.600 25.000 1684020.000       NaN 0.000    ND       2
# 2387   118  910 80.400 25.000         NaN       NaN 0.000    ND       2
# 2479   184  923 78.300 24.000 1235930.000   944.629 0.000    ND       1
# 2482   184  923 78.300 24.000 1235930.000   863.926 0.000    ND       1
# 2647   685  906 89.600 23.000         NaN       NaN 0.000    ND       1
# 2650   602  919 70.700 25.000         NaN       NaN 0.000    ND       1
# 2810  1092  883 74.300 24.000 1325590.000   949.214 0.000    ND       2
#
#      Converted  num_MRI
# 142          0        1
# 513          0        2
# 560          1        5
# 879          0        1
# 1234         0        4
# 1507         0        4
# 2080         1        5
# 2387         1        5
# 2479         0        5
# 2482         0        5
# 2647         0        4
# 2650         0        4
# 2810         4        5
# 0
# 4

# %% [markdown]
# CHANGE ! A score between 22-25 is not abnormally low. Additionally, one of the subjects that obtained an MMSE score of 25 is 90 years old, it is plausible for a 90 year old without dementia to score slightly lower due to normal effects of aging, additionally, there are 38 other 90 year old subjects within this sample. I will keep this subject and others who scored below 25 in the dataset in order to represent the true population of adults ages 50-100

# %%
x = ADNI_D.loc[ADNI_D['Group']=='AD', 'MMSE'].dropna()
plt.hist(x,bins=10)
plt.show()

# %%
x = ADNI_D.loc[ADNI_D['Group']=='MCI', 'MMSE'].dropna()
plt.hist(x,bins=10)
plt.show()

# %%
print(len(ADNI_D[(ADNI_D['MMSE']<=15)&(ADNI_D['Group']=='MCI')]))
# Out:
# 7

# %% [markdown]
# There are 7 subjects within the lower range of MMSE scores of subjects diagnosed with MCI, removing these subjects will not affect the skew of the data, also, extreme values of brain volume data have been removed, therefore these subjects will remain in the dataset

# %%
histAD = ADNI_D.loc[ADNI_D['Group']=='AD', 'MMSE']
plt.hist(histAD,bins=10)
plt.show()

# %%
print(ADNI_D[(ADNI_D['MMSE']<10)&(ADNI_D['Group']=='AD')])
#print(ADNI_D[ADNI_D['Subject_ID']=='OAS2_0048'])
# Out:
#        RID DAYS    AGE  MMSE        EICV  BRAINVOL   CDR Group  counts  \
# 421     93  194 77.200 5.000 1294920.000   834.933 3.000    AD       1
# 957     78  378 76.000 9.000 1513820.000  1027.473 3.000    AD       1
# 989    565  169 74.600 8.000         NaN       NaN 2.000    AD       1
# 1528    93  543 77.200 4.000 1294920.000   805.156 3.000    AD       1
# 1687    88  583 65.600 1.000         NaN       NaN 3.000    AD       2
# 2025   730  538 70.600 8.000         NaN       NaN 2.000    AD       1
# 2048   565  540 74.600 2.000 1433270.000   995.854 3.000    AD       1
# 2100   750  542 75.600 8.000 1193230.000   731.803 2.000    AD       2
# 2254    50  895 77.600 8.000 1720480.000       NaN 2.000    AD       1
# 2281  1082  548 69.500 5.000         NaN       NaN 2.000    AD       1
# 2294   793  650 68.900 7.000 1519580.000  1002.054 2.000    AD       1
# 2337   102  914 70.300 5.000         NaN       NaN 1.000    AD       2
# 2455  1409    0 65.900 0.000         NaN       NaN 2.000    AD       1
# 2477  1368  501 75.200 5.000 1267160.000   821.314 1.000    AD       1
# 2792  1082  912 69.500 0.000         NaN       NaN 3.000    AD       1
# 2824  1157  914 84.900 9.000         NaN       NaN 2.000    AD       1
# 2922  1368  887 75.200 7.000         NaN       NaN 2.000    AD       1
# 2926  1262  948 72.700 4.000         NaN       NaN 2.000    AD       1
#
#      Converted  num_MRI
# 421          0        3
# 957          0        3
# 989          0        3
# 1528         0        3
# 1687         3        3
# 2025         0        3
# 2048         0        3
# 2100         3        3
# 2254         0        5
# 2281         0        4
# 2294         0        3
# 2337         3        5
# 2455         0        1
# 2477         0        4
# 2792         0        4
# 2824         0        3
# 2922         0        4
# 2926         0        7

# %% [markdown]
# It seems that there is an overlap in the range of MMSE scores for each diagnosis group suggesting tha there is a complex relationship, MMSE values will only be used where there is corresponding brain volume data

# %% [markdown]
# # Multivariate Outliers / Mahalanobis Distance

# %%
'''
/***************************************************************************************
*    Title: How To Calculate Mahalanobis Distance in Python
*    Author: Bhu Wanesh
*    Date: 2022
*    Availability: https://www.geeksforgeeks.org/how-to-calculate-mahalanobis-distance-in-python/
*
***************************************************************************************/
'''

# create dataframe for each group with only continuous variables

cont_AD = ADNI_D.loc[ADNI['Group']=='AD', ['BRAINVOL','EICV']]
cont_AD.dropna(inplace=True) # can only calcualte MD for rows/subjects with both BRAINVOL and EICV data
cont_AD_data = cont_AD.to_numpy()
#ADNI_contMCI =
#ADNI_contND =

# %%
len(cont_AD_data)
# Out:
# 39

# %%
eicv = ADNI_D.loc[(ADNI_D['Group']=='AD')&(ADNI_D['EICV'].notnull()), 'EICV']
# Out:
# 4      1709170.000
# 6      1478220.000
# 15     1746800.000
# 25     1582760.000
# 29     1720480.000
#            ...
# 2590   1378070.000
# 2812   1613640.000
# 2829   1165730.000
# 2837   1319310.000
# 2872   1239020.000
# Name: EICV, Length: 238, dtype: float64

# %%
y_mu = cont_AD - np.mean(cont_AD[['BRAINVOL', 'EICV']])
print(y_mu)
print(cont_AD)
# Out:
#       BRAINVOL       EICV  calculateMahalanobis
# 280     77.607 155031.500                   NaN
# 336    120.806  39401.500                   NaN
# 389        NaN        NaN                   NaN
# 470     25.957  39481.500                   NaN
# 622        NaN        NaN                   NaN
# ...        ...        ...                   ...
# 2946   -67.096        NaN                   NaN
# 2954       NaN        NaN                   NaN
# 2955    12.268        NaN                   NaN
# 2979   197.277        NaN                   NaN
# 2980       NaN        NaN                   NaN
#
# [124 rows x 3 columns]
#       BRAINVOL        EICV  calculateMahalanobis
# 280   1096.393 1635130.000                   NaN
# 336   1139.592 1519500.000                   NaN
# 389        NaN         NaN                   NaN
# 470   1044.743 1519580.000                   NaN
# 622        NaN         NaN                   NaN
# ...        ...         ...                   ...
# 2946   951.690         NaN                   NaN
# 2954       NaN         NaN                   NaN
# 2955  1031.054         NaN                   NaN
# 2979  1216.063         NaN                   NaN
# 2980       NaN         NaN                   NaN
#
# [124 rows x 3 columns]
# /Users/cex/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
np.mean(cont_AD[['BRAINVOL', 'EICV']])
# Out:
# /Users/cex/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# BRAINVOL      1018.786
# EICV       1480098.500
# dtype: float64

# %%
# calculateMahalanobis function to calculate
# the Mahalanobis distance
def calculateMahalanobis(y=None, data=None, cov=None):
  
    y_mu = y - np.mean(data)
    if not cov:
        cov = np.cov(data.values.T)
    inv_covmat = np.linalg.inv(cov)
    left = np.dot(y_mu, inv_covmat)
    mahal = np.dot(left, y_mu.T)
    return mahal.diagonal()
  
# create new column in dataframe that contains 
# Mahalanobis distance for each row
cont_AD['calculateMahalanobis'] = calculateMahalanobis(y=cont_AD, data=cont_AD[['BRAINVOL', 'EICV']])
print(cont_AD)
# Out:
#       BRAINVOL        EICV  calculateMahalanobis
# 280   1096.393 1635130.000                   NaN
# 336   1139.592 1519500.000                   NaN
# 389        NaN         NaN                   NaN
# 470   1044.743 1519580.000                   NaN
# 622        NaN         NaN                   NaN
# ...        ...         ...                   ...
# 2946   951.690         NaN                   NaN
# 2954       NaN         NaN                   NaN
# 2955  1031.054         NaN                   NaN
# 2979  1216.063         NaN                   NaN
# 2980       NaN         NaN                   NaN
#
# [124 rows x 3 columns]
# /Users/cex/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics

# %% [markdown]
# # Data structures for converted groups

# %%
print(len(ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3)]))
print(len(ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3)]))
print(len(ADNI_D.loc[(ADNI_D['MMSE'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3)]))
# Out:
# 220
# 207
# 337

# %%
BV3 = ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3),'BRAINVOL'][0:207]
IV3 = ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3),'EICV'][0:207]
MMSE3 = ADNI_D.loc[(ADNI_D['MMSE'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==3),'MMSE'][0:207]

BV0 = ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0),'BRAINVOL'][0:207]
IV0 = ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0),'EICV'][0:207]
MMSE0 = ADNI_D.loc[(ADNI_D['MMSE'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0),'MMSE'][0:207]

# %%
IV3
# Out:
# 0      1237130.000
# 20     1451220.000
# 21     1407900.000
# 56     1266890.000
# 57     1266890.000
#            ...
# 2516   1699000.000
# 2521   1242060.000
# 2531   1395830.000
# 2532   1395830.000
# 2556   1596820.000
# Name: EICV, Length: 207, dtype: float64

# %%
print(len(ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0)]))
print(len(ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0)]))
print(len(ADNI_D.loc[(ADNI_D['MMSE'].notnull())&(ADNI_D['Group']=='MCI')&(ADNI_D['Converted']==0)]))
# Out:
# 539
# 462
# 1012

# %%
# make an array of labels = np.ones and np.zeros
ones = np.ones((3,207))
zeros = np.zeros((3,207))

# %%
pd.merge(
            pd.merge(
                 pd.merge(MMSE_df,IV_df, how='outer',on=['RID','EXAMDATE']),
                        BV_df,how='outer',on=['RID','EXAMDATE']), 
                            CDR_df,how='outer',on=['RID','EXAMDATE'])

# %%
# NOT USING MMSE AS RANGE TOO UNPREDICTABLE
BV = pd.concat([BV3,BV0],ignore_index=True)
BV = (BV-min(BV))/(max(BV)-min(BV))

IV = pd.concat([IV3,IV0],ignore_index=True)
IV = (IV-min(IV))/(max(IV)-min(IV))

ones = pd.Series(np.ones(207))
zeros = pd.Series(np.zeros(207))
labels = pd.concat([ones,zeros],ignore_index=True)

converted = pd.concat([BV,IV,labels], ignore_index=True, axis=1)
converted.head()
# Out:
#       0     1     2
# 0 0.307 0.194 1.000
# 1 0.593 0.436 1.000
# 2 0.505 0.387 1.000
# 3 0.475 0.227 1.000
# 4 0.285 0.227 1.000

# %%
BV
# Out:
# 0     0.307
# 1     0.593
# 2     0.505
# 3     0.475
# 4     0.285
#        ...
# 409   0.258
# 410   0.549
# 411   0.598
# 412   0.347
# 413   0.788
# Name: BRAINVOL, Length: 414, dtype: float64

# %%
BV = (BV-min(BV))/(max(BV)-min(BV))

# %%
X = converted.drop(2,axis=1)
y = converted[2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

# %%
X_train
# Out:
#         0     1
# 279 0.553 0.372
# 301 0.418 0.479
# 399 0.490 0.475
# 184 0.375 0.711
# 260 0.620 0.711
# ..    ...   ...
# 381 0.515 0.851
# 52  0.519 0.374
# 220 0.565 0.553
# 66  0.691 0.637
# 405 0.652 0.720
#
# [248 rows x 2 columns]

# %% [markdown]
# # Training the algorithm

# %% [markdown]
# # polynomial kernel

# %%
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[50 34]
#  [33 49]]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60        84
#          1.0       0.59      0.60      0.59        82
#
#     accuracy                           0.60       166
#    macro avg       0.60      0.60      0.60       166
# weighted avg       0.60      0.60      0.60       166
#
# Accuracy: 0.5963855421686747

# %% [markdown]
# # Gaussian Kernel

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[61 23]
#  [41 41]]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.73      0.66        84
#          1.0       0.64      0.50      0.56        82
#
#     accuracy                           0.61       166
#    macro avg       0.62      0.61      0.61       166
# weighted avg       0.62      0.61      0.61       166
#
# Accuracy: 0.6144578313253012

# %% [markdown]
# # Sigmoid kernel

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[ 2 82]
#  [10 72]]
#               precision    recall  f1-score   support
#
#          0.0       0.17      0.02      0.04        84
#          1.0       0.47      0.88      0.61        82
#
#     accuracy                           0.45       166
#    macro avg       0.32      0.45      0.33       166
# weighted avg       0.32      0.45      0.32       166
#
# Accuracy: 0.4457831325301205

# %% [markdown]
# # AD VS MCI VS ND

# %%
ADBV = ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='AD'),'BRAINVOL'][0:238]
ADIV = ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='AD'),'EICV'][0:238]

MCIBV = ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='MCI'),'BRAINVOL'][0:238]
MCIIV = ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='MCI'),'EICV'][0:238]

NDBV = ADNI_D.loc[(ADNI_D['BRAINVOL'].notnull())&(ADNI_D['Group']=='ND'),'BRAINVOL'][0:238]
NDIV = ADNI_D.loc[(ADNI_D['EICV'].notnull())&(ADNI_D['Group']=='ND'),'EICV'][0:238]

print(len(ADBV),len(ADIV),len(MCIBV),len(MCIIV),len(NDBV),len(NDIV))
# Out:
# 238 238 238 238 238 238

# %%
BV = pd.concat([ADBV,MCIBV,NDBV],ignore_index=True)
BV = (BV-min(BV))/(max(BV)-min(BV))

IV = pd.concat([ADIV,MCIIV,NDIV],ignore_index=True)
IV = (IV-min(IV))/(max(IV)-min(IV))

ones = pd.Series(np.ones(238))

x = [2]*238
twos = pd.Series(x)

z = [3]*238
threes = pd.Series(z)
labels = pd.concat([ones,twos,threes],ignore_index=True)

converted = pd.concat([BV,IV,labels], ignore_index=True, axis=1)
converted
# Out:
#         0     1     2
# 0   0.680 0.728 1.000
# 1   0.530 0.467 1.000
# 2   0.778 0.771 1.000
# 3   0.535 0.585 1.000
# 4   0.628 0.741 1.000
# ..    ...   ...   ...
# 709 0.366 0.513 3.000
# 710 0.337 0.513 3.000
# 711 0.525 0.700 3.000
# 712 0.318 0.468 3.000
# 713 0.282 0.440 3.000
#
# [714 rows x 3 columns]

# %%
BV = pd.concat([ADBV,MCIBV,NDBV],ignore_index=True)
BV = (BV-min(BV))/(max(BV)-min(BV))

IV = pd.concat([ADIV,MCIBV,NDIV],ignore_index=True)
IV = (IV-min(IV))/(max(IV)-min(IV))

ones = pd.Series(np.ones(238))

x = [2]*238
twos = pd.Series(x)

z = [3]*238
threes = pd.Series(z)

labels = pd.concat([ones,twos,threes],ignore_index=True)

converted = pd.concat([BV,IV,labels], ignore_index=True, axis=1)

print(converted)
# Out:
#         0     1     2
# 0   0.680 0.917 1.000
# 1   0.530 0.793 1.000
# 2   0.778 0.937 1.000
# 3   0.535 0.849 1.000
# 4   0.628 0.923 1.000
# ..    ...   ...   ...
# 709 0.366 0.815 3.000
# 710 0.337 0.815 3.000
# 711 0.525 0.903 3.000
# 712 0.318 0.793 3.000
# 713 0.282 0.780 3.000
#
# [714 rows x 3 columns]

# %%
X = converted.drop(2,axis=1)
y = converted[2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4)

# %% [markdown]
# # polynomial kernel

# %%
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[65  0 27]
#  [ 0 99  0]
#  [55  0 40]]
#               precision    recall  f1-score   support
#
#          1.0       0.54      0.71      0.61        92
#          2.0       1.00      1.00      1.00        99
#          3.0       0.60      0.42      0.49        95
#
#     accuracy                           0.71       286
#    macro avg       0.71      0.71      0.70       286
# weighted avg       0.72      0.71      0.71       286
#
# Accuracy: 0.7132867132867133

# %% [markdown]
# # Gaussian Kernel

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[52 44]
#  [27 68]]
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.54      0.59        96
#          1.0       0.61      0.72      0.66        95
#
#     accuracy                           0.63       191
#    macro avg       0.63      0.63      0.63       191
# weighted avg       0.63      0.63      0.63       191
#
# Accuracy: 0.6282722513089005

# %% [markdown]
# # no sigmoid kernel as this is binary

# %% [markdown]
# # Sigmoid kernel

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[ 0 96]
#  [ 3 92]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.49      0.97      0.65        95
#
#     accuracy                           0.48       191
#    macro avg       0.24      0.48      0.33       191
# weighted avg       0.24      0.48      0.32       191
#
# Accuracy: 0.4816753926701571

# %% [markdown]
# # Deep learning

# %%
ADNI.loc[ADNI.BRAINVOL.notnull()]
# Out:
#         RID  DAYS    AGE   MMSE  EICV  BRAINVOL  CDR Converted Group  counts  \
# 0      4404     0    NaN    NaN   NaN   928.720  NaN      none     U       1
# 1      4404     0    NaN    NaN   NaN   924.819  NaN      none     U       1
# 2       873     0    NaN    NaN   NaN   903.734  NaN      none     U       3
# 3       563     0    NaN    NaN   NaN  1027.192  NaN      none     U       2
# 4       553     0    NaN    NaN   NaN  1059.470  NaN      none     U       2
# ...     ...   ...    ...    ...   ...       ...  ...       ...   ...     ...
# 21434  6038  1532    NaN    NaN   NaN   947.510  NaN      none     U       1
# 21445  6116  1478    NaN    NaN   NaN  1112.920  NaN      none     U       1
# 21448  4212  3745 64.700 29.000   NaN  1227.800  NaN      none     U       1
# 21454  4076  3839    NaN    NaN   NaN   914.578  NaN      none     U       1
# 21455  4076  3839    NaN    NaN   NaN   917.391  NaN      none     U       1
#
#        num_MRI
# 0           23
# 1           23
# 2           11
# 3           12
# 4           18
# ...        ...
# 21434        8
# 21445        7
# 21448       17
# 21454       24
# 21455       24
#
# [13638 rows x 11 columns]

# %%
ADNI.loc[ADNI.EICV.notnull()]
# Out:
#        RID  DAYS    AGE   MMSE        EICV  BRAINVOL   CDR Converted Group  \
# 14       2     0    NaN    NaN 1845620.000  1251.466   NaN      none     U
# 15       3     0    NaN    NaN 1709170.000  1186.021   NaN      none     U
# 16       5     0    NaN    NaN 1599490.000  1176.689   NaN      none     U
# 20       8     0    NaN    NaN 1329160.000   988.806   NaN      none     U
# 21       7     0    NaN    NaN 1308700.000   916.973   NaN      none     U
# ...    ...   ...    ...    ...         ...       ...   ...       ...   ...
# 6621  1406  1116 61.100 29.000 1457370.000       NaN   NaN      none     U
# 6642  1394  1126    NaN    NaN 1631320.000  1057.187   NaN      none     U
# 6681  1260  1272 71.200 26.000 1485890.000  1101.513 0.500      none   MCI
# 6701  1425  1106 75.600 24.000 1286350.000   906.645 0.500      none   MCI
# 6702  1418  1117 81.500 30.000 1480730.000  1025.732 0.500      none   MCI
#
#       counts  num_MRI
# 14         2       12
# 15         3        5
# 16         3        6
# 20         2       11
# 21         2        6
# ...      ...      ...
# 6621       2       10
# 6642       3       10
# 6681       2        9
# 6701       2       11
# 6702       2       21
#
# [3414 rows x 11 columns]

# %%
# Out:
#        RID    EXAMDATE     EICV
# 0        2  2005-08-26  1845620
# 1        3  2005-09-01  1709170
# 2        3  2006-03-13  1709170
# 3        3  2006-09-12  1709170
# 4        3  2007-09-12  1709170
# ...    ...         ...      ...
# 3123  1427  2008-09-02  1472690
# 3124  1427  2009-03-12  1472690
# 3125  1430  2007-09-07  1177000
# 3126  1430  2008-04-04  1177000
# 3127  1435  2007-09-07  1489320
#
# [3128 rows x 3 columns]

# %% [markdown]
# # References
#
# [1] Mayo Clinic, “Alzheimer's disease,” Mayo Clinic, 19-Feb-2022. [Online]. Available: https://www.mayoclinic.org/diseases-conditions/alzheimers-disease/symptoms-causes/syc-20350447#:~:text=There%20is%20no%20treatment%20that,or%20infection%20%E2%80%94%20result%20in%20death. [Accessed: 06-Dec-2022].
#
# [2] Centers for Disease Control and Prevention, “About dementia?,” Centers for Disease Control and Prevention, 05-Apr-2019. [Online]. Available: https://www.cdc.gov/aging/dementia/index.html#:~:text=Dementia%20is%20not%20a%20specific,a%20part%20of%20normal%20aging. [Accessed: 06-Dec-2022].
#
# [3] D. E. Barnes and K. Yaffe, “The projected effect of risk factor reduction on alzheimer's disease prevalence,” The Lancet Neurology, vol. 10, no. 9, pp. 819–828, 2011.
#
# [4] M. Van Bulck, A. Sierra-Magro, J. Alarcon-Gil, A. Perez-Castillo, and J. Morales-Garcia, “Novel approaches for the treatment of alzheimer’s and parkinson’s disease,” International Journal of Molecular Sciences, vol. 20, no. 3, p. 719, 2019.
#
# [5] G. Moya-Alvarado, N. Gershoni-Emek, E. Perlson, and F. C. Bronfman, “Neurodegeneration and alzheimer's disease (AD). what can proteomics tell us about the alzheimer's brain?,” Molecular &amp; Cellular Proteomics, vol. 15, no. 2, pp. 409–425, 2016.
#
# [6] M. S. Albert et al., “The diagnosis of mild cognitive impairment due to alzheimer's disease: Recommendations from the National Institute on aging‐alzheimer's association workgroups on diagnostic guidelines for alzheimer's disease,” Alzheimer's &amp; Dementia, vol. 7, no. 3, pp. 270–279, 2011.
#
# [7] R. A. Sperling et al., “Toward defining the preclinical stages of alzheimer's disease: Recommendations from the National Institute on aging‐alzheimer's association workgroups on diagnostic guidelines for alzheimer's disease,” Alzheimer's &amp; Dementia, vol. 7, no. 3, pp. 280–292, 2011.
#
# [8] C. R. Jack et al., “Nia‐AA Research Framework: Toward a biological definition of alzheimer's disease,” Alzheimer's &amp; Dementia, vol. 14, no. 4, pp. 535–562, 2018.
#
# [9] C. Mathis, Y. Wang, and W. Klunk, “Imaging β-amyloid plaques and neurofibrillary tangles in the aging human brain,” Current Pharmaceutical Design, vol. 10, no. 13, pp. 1469–1492, 2004.
#
# [10] A. J. Mitchell and M. Shiri-Feshki, “Rate of progression of mild cognitive impairment to dementia - meta-analysis of 41 robust inception cohort studies,” Acta Psychiatrica Scandinavica, vol. 119, no. 4, pp. 252–265, 2009.
#
# [11] D. Purves, “Brain Imaging Techniques,” in Neuroscience, Sunderland, MA: Sinauer Associates, 2012.
#
# [12] A. Chandra, G. Dervenoulas, and M. Politis, “Magnetic Resonance Imaging in alzheimer’s disease and mild cognitive impairment,” Journal of Neurology, vol. 266, no. 6, pp. 1293–1302, 2018.
#
# [13] B. G. Tabachnick and L. S. Fidell, Using multivariate statistics, 7th ed. Upper Saddle River, NJ: Pearson, 2018.
